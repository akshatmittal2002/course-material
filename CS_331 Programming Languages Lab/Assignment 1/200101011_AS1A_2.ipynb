# %% [markdown]
# # **Programming Lab Assignment - 1A**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Complete the Bubble Sort Program**

# %% [markdown]
# Name: Akshat Mittal
#
# Roll_No: 200101011

# %%
# Write the path of file uploaded in your drive. 
with open('/content/drive/MyDrive/CS_331 Programming Languages Lab/Assignment 1A/data_file.txt', 'r') as f:
    data = f.read()
# Conversion of string list data to integer list.
raw = [int(i) for i in data.split()]

# %%
# Code to find the maximum 20 values from the file.
max_20=[]
for i in range(0, 20):
    max1 = 0
    for j in range(len(raw)):    
        if raw[j] > max1:
            max1 = raw[j];
                 
    raw.remove(max1);
    max_20.append(max1)
         
print(max_20)
# Out:
# [2334, 2302, 2260, 2257, 2251, 2248, 2244, 2241, 2234, 2234, 2230, 2229, 2224, 2223, 2214, 2209, 2207, 2206, 2204, 2198]

# %%
# .................Write your BUBBLE SORT CODE here.......................
n = len(max_20)
for i in range(n-1):
  for j in range(n-i-1):
    # swap if order mismatch
    if max_20[j] > max_20[j+1]:
      temp = max_20[j]
      max_20[j] = max_20[j+1]
      max_20[j+1] = temp
# print result to check
print(max_20)
# Out:
# [2198, 2204, 2206, 2207, 2209, 2214, 2223, 2224, 2229, 2230, 2234, 2234, 2241, 2244, 2248, 2251, 2257, 2260, 2302, 2334]

# %%
# ........Write the sorted array into a file named "B_SORT.txt"...........
# open file in write mode
file = open('/content/drive/MyDrive/CS_331 Programming Languages Lab/Assignment 1A/B_SORT.txt','w')
# write sorted list in file
for i in max_20:
  file.write(str(i)+"\n")
# close the file
file.close()
